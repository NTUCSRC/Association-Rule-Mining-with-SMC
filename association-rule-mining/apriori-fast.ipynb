# %% [markdown]
# # Apriori Algorithms

# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori

# %%
df = pd.read_csv('../data/clean/diabetes_all.csv')
df.shape
# Out:
# (35346, 64)

# %%
apriori(df, min_support=0.6, use_colnames=True)
# Out:
#      support                                  itemsets
# 0   0.752674                                  (HighBP)
# 1   0.670118                                (HighChol)
# 2   0.993182                               (CholCheck)
# 3   0.630538                            (PhysActivity)
# 4   0.756408                                 (Veggies)
# 5   0.959769                           (AnyHealthcare)
# 6   0.662112                              (MentHlth_0)
# 7   0.748628                       (HighBP, CholCheck)
# 8   0.723844                   (HighBP, AnyHealthcare)
# 9   0.666299                     (CholCheck, HighChol)
# 10  0.643750                 (HighChol, AnyHealthcare)
# 11  0.626832                 (CholCheck, PhysActivity)
# 12  0.751514                      (Veggies, CholCheck)
# 13  0.954705                (CholCheck, AnyHealthcare)
# 14  0.658519                   (CholCheck, MentHlth_0)
# 15  0.607452             (AnyHealthcare, PhysActivity)
# 16  0.728060                  (Veggies, AnyHealthcare)
# 17  0.639818               (AnyHealthcare, MentHlth_0)
# 18  0.720647        (AnyHealthcare, HighBP, CholCheck)
# 19  0.640751      (CholCheck, HighChol, AnyHealthcare)
# 20  0.604679  (CholCheck, AnyHealthcare, PhysActivity)
# 21  0.724382       (Veggies, CholCheck, AnyHealthcare)
# 22  0.636960    (CholCheck, AnyHealthcare, MentHlth_0)
